# %% [raw]
# ---
# description: Notes on data gathering and prepping process.
# output-file: data.html
# title: Data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->
