# %% [raw]
# ---
# description: Roadmap and To-Do
# output-file: roadmap.html
# title: Roadmap
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # To Do:
# - [] setup process
# - [] training process
# - [] benchmarks
# - [] data
#
#
#
# https://developer.nvidia.com/cuda-gpus
#
#
# # Roadmap
# -
# -
